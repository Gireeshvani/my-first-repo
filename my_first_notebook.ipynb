# %% [markdown]
# <a href="https://colab.research.google.com/github/Gireeshvani/my-first-repo/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hardware = '''Hardware refers to the physical parts of a computer that you can see and touch.
Examples: keyboard, mouse, monitor, CPU, hard disk
These are real, tangible components
Example: A keyboard – you can physically press its keys.'''

# %%
software = '''Software refers to the programs or instructions that tell the hardware what to do.
Examples: operating systems, apps, games, browsers
You cannot touch software, but you can use it
Example: python – a program used to create code.'''

# %%
print(hardware)
# Out:
# Hardware refers to the physical parts of a computer that you can see and touch.
# Examples: keyboard, mouse, monitor, CPU, hard disk
# These are real, tangible components
# Example: A keyboard – you can physically press its keys.

# %%
print(software)
# Out:
# Software refers to the programs or instructions that tell the hardware what to do.
# Examples: operating systems, apps, games, browsers
# You cannot touch software, but you can use it
# Example: python – a program used to create code.

# %% [markdown]
# Difference between hardware and software

# %%
dif_hardware = 'physical touch'

# %%
dif_software = 'not phusical touch'

# %%
print (dif_hardware)
# Out:
# physical touch

# %%
print (dif_software)
# Out:
# not phusical touch
